# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from keras.models import Model, Sequential
from keras.layers import Input, Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict

# %%
# Cargar los datos desde el CSV
df = pd.read_csv(r'C:\Users\Fabian\Desktop\PROYECTO\canciones\caracteristicas_songs_etiquetadas.csv')
df.head()
# Out:
#                                               Nombre     Artista       Tempo  \
# 0   El Tema De La Película #Gru 3 Mi Villano Favo...       Morat   95.703125
# 1                                                 #3   Bad Bunny  107.666016
# 2                                                  +      Aitana  107.666016
# 3                                         10 Minutos  Miki Núñez  161.499023
# 4                                                 11    Corderas   89.102909
#
#    Tonalidad_1  Tonalidad_2  Tonalidad_3  RMS_Energy  Zero_Crossing_Rate  \
# 0     0.428299     0.428980     0.332504    0.116094            0.080412
# 1     0.445583     0.318513     0.312020    0.190074            0.137812
# 2     0.423968     0.343299     0.262612    0.227739            0.119669
# 3     0.405336     0.504356     0.336348    0.276710            0.117588
# 4     0.408914     0.347925     0.486865    0.218130            0.100745
#
#        MFCC_1     MFCC_2     MFCC_3  Spectral_Centroid  Lable_sent
# 0 -128.264940  89.178290  10.359152        2297.262265           1
# 1 -103.382220  48.632713  12.663226        3280.312481           0
# 2  -44.269390  75.249800   5.470774        2795.030171           0
# 3  -23.786980  80.557060  -7.478475        2613.423737           1
# 4  -48.194275  87.605470   0.325630        2344.454151           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nombre              1084 non-null   object
#  1   Artista             1084 non-null   object
#  2   Tempo               1084 non-null   float64
#  3   Tonalidad_1         1084 non-null   float64
#  4   Tonalidad_2         1084 non-null   float64
#  5   Tonalidad_3         1084 non-null   float64
#  6   RMS_Energy          1084 non-null   float64
#  7   Zero_Crossing_Rate  1084 non-null   float64
#  8   MFCC_1              1084 non-null   float64
#  9   MFCC_2              1084 non-null   float64
#  10  MFCC_3              1084 non-null   float64
#  11  Spectral_Centroid   1084 non-null   float64
#  12  Lable_sent          1084 non-null   int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 110.2+ KB

# %%
# Elimina las columnas 'Nombre' y 'Artista'
df = df.drop(columns=['Nombre', 'Artista'])

# Establece X (características) y y (etiqueta)
X = df.drop(columns=['Lable_sent']).values
y = df['Lable_sent'].values

# %%
# Paso 1: Preprocesamiento de datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Definir la entrada
inputs = Input(shape=(X_train.shape[1],))

# %%
def model1(inputs):
    x = Dense(128, activation='relu')(inputs)
    outputs = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model, 'Red Neuronal 1'

def model2(inputs):
    x = Dense(64, activation='relu')(inputs)
    x = Dense(32, activation='relu')(x)
    outputs = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model, 'Red Neuronal 2'

# %%
# Función de optimización
def optimize_model(X_train, y_train, X_test, y_test, model_func):
    # Construir el modelo utilizando la función proporcionada
    model, model_name = model_func(inputs)
    # Compilar el modelo
    model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])
    # Entrenar el modelo
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test),
                        callbacks=[EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)])
    # Evaluar el modelo
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Modelo: {model_name}, Pérdida: {loss}, Precisión: {accuracy}")
    return model_name, model, history

# %%
# Seleccionar modelos neuronales para probar
neural_models = [
    model1,
    model2
]
# Seleccionar modelos no neuronales
non_neural_models = [
    (SVC(kernel='linear'), 'SVM'),
    (RandomForestClassifier(), 'Random Forest'),
    (XGBClassifier(), 'XGBoost'),
    (LogisticRegression(), 'Logistic Regression'),
    (KNeighborsClassifier(), 'K-Nearest Neighbors')
]

# %%
# Almacenar resultados de cada modelo
results = []

# Compilar y entrenar los modelos neuronales
for model_func in neural_models:
    model_name, model, history = optimize_model(X_train, y_train, X_test, y_test, model_func)
    results.append((model_name, model, history))
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4532 - loss: 0.7125 - val_accuracy: 0.7834 - val_loss: 0.5447
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7896 - loss: 0.5176 - val_accuracy: 0.7880 - val_loss: 0.4712
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7680 - loss: 0.4817 - val_accuracy: 0.7972 - val_loss: 0.4482
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7682 - loss: 0.4707 - val_accuracy: 0.8018 - val_loss: 0.4379
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7741 - loss: 0.4674 - val_accuracy: 0.7926 - val_loss: 0.4350
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4183 - val_accuracy: 0.7926 - val_loss: 0.4321
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7869 - loss: 0.4260 - val_accuracy: 0.7972 - val_loss: 0.4273
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7971 - loss: 0.4217 - val_accuracy: 0.8065 - val_loss: 0.4235
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.4589 - val_accuracy: 0.8111 - val_loss: 0.4250
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7872 - loss: 0.4293 - val_accuracy: 0.8157 - val_loss: 0.4255
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.4263 - val_accuracy: 0.8203 - val_loss: 0.4228
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7850 - loss: 0.4366 - val_accuracy: 0.8203 - val_loss: 0.4214
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7935 - loss: 0.4205 - val_accuracy: 0.8157 - val_loss: 0.4183
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7945 - loss: 0.4030 - val_accuracy: 0.8111 - val_loss: 0.4178
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8204 - loss: 0.3978 - val_accuracy: 0.8157 - val_loss: 0.4170
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8021 - loss: 0.4264 - val_accuracy: 0.8111 - val_loss: 0.4160
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8070 - loss: 0.3999 - val_accuracy: 0.8203 - val_loss: 0.4165
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8038 - loss: 0.3904 - val_accuracy: 0.8111 - val_loss: 0.4157
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7796 - loss: 0.4385 - val_accuracy: 0.8065 - val_loss: 0.4129
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8047 - loss: 0.4164 - val_accuracy: 0.8157 - val_loss: 0.4107
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8195 - loss: 0.3908 - val_accuracy: 0.8157 - val_loss: 0.4109
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8274 - loss: 0.3870 - val_accuracy: 0.8157 - val_loss: 0.4109
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8287 - loss: 0.3892 - val_accuracy: 0.8203 - val_loss: 0.4087
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8244 - loss: 0.4098 - val_accuracy: 0.8157 - val_loss: 0.4116
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8170 - loss: 0.3786 - val_accuracy: 0.8203 - val_loss: 0.4100
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8124 - loss: 0.4205 - val_accuracy: 0.8203 - val_loss: 0.4092
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.8269 - loss: 0.4032
# Modelo: Red Neuronal 1, Pérdida: 0.4087444841861725, Precisión: 0.8202764987945557
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5575 - loss: 0.6611 - val_accuracy: 0.7788 - val_loss: 0.4810
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7628 - loss: 0.5156 - val_accuracy: 0.7788 - val_loss: 0.4441
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.4523 - val_accuracy: 0.7742 - val_loss: 0.4292
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7915 - loss: 0.4650 - val_accuracy: 0.7880 - val_loss: 0.4272
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7945 - loss: 0.4281 - val_accuracy: 0.7880 - val_loss: 0.4260
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8065 - loss: 0.4291 - val_accuracy: 0.7926 - val_loss: 0.4250
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.4105 - val_accuracy: 0.8018 - val_loss: 0.4234
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7985 - loss: 0.4315 - val_accuracy: 0.8065 - val_loss: 0.4240
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8046 - loss: 0.4386 - val_accuracy: 0.8018 - val_loss: 0.4231
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7958 - loss: 0.4412 - val_accuracy: 0.8018 - val_loss: 0.4215
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7842 - loss: 0.4234 - val_accuracy: 0.8157 - val_loss: 0.4204
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7832 - loss: 0.4375 - val_accuracy: 0.8157 - val_loss: 0.4180
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8059 - loss: 0.4175 - val_accuracy: 0.8157 - val_loss: 0.4167
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8019 - loss: 0.4134 - val_accuracy: 0.8157 - val_loss: 0.4154
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.3847 - val_accuracy: 0.8111 - val_loss: 0.4127
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0.3884 - val_accuracy: 0.8157 - val_loss: 0.4136
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7841 - loss: 0.4132 - val_accuracy: 0.8203 - val_loss: 0.4155
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8036 - loss: 0.4000 - val_accuracy: 0.8157 - val_loss: 0.4140
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.8175 - loss: 0.4092
# Modelo: Red Neuronal 2, Pérdida: 0.4126972556114197, Precisión: 0.8110598921775818

# %%
# Compilar y entrenar los modelos no neuronales
for model, model_name in non_neural_models:
    scores = cross_val_score(model, X_train, y_train, cv=5)
    mean_accuracy = scores.mean()
    # Calcular F1-score
    y_pred = cross_val_predict(model, X_train, y_train, cv=5)
    f1 = f1_score(y_train, y_pred)
    results.append((model_name, mean_accuracy, f1))

# %%
# Imprimir resultados de todos los modelos
for result in results:
    model_name = result[0]
    if isinstance(result[1], float):  # Si es un modelo no neuronal
        accuracy = result[1]
        print(f"Modelo: {model_name}, Accuracy: {accuracy}, F1-score: {f1}")
    else:  # Si es un modelo neuronal
        model = result[1]
        history = result[2]
        accuracy = history.history.get('val_accuracy')[-1] if history else None
        loss = history.history.get('val_loss')[-1] if history else None
        print(f"{model_name}: Accuracy: {accuracy}, Loss: {loss}")
# Out:
# Red Neuronal 1: Accuracy: 0.8202764987945557, Loss: 0.40915167331695557
# Red Neuronal 2: Accuracy: 0.8156682252883911, Loss: 0.4139537811279297
# Modelo: SVM, Accuracy: 0.778552920071756, F1-score: 0.3532934131736527
# Modelo: Random Forest, Accuracy: 0.7820809248554913, F1-score: 0.3532934131736527
# Modelo: XGBoost, Accuracy: 0.7693508736960999, F1-score: 0.3532934131736527
# Modelo: Logistic Regression, Accuracy: 0.7889509002724072, F1-score: 0.3532934131736527
# Modelo: K-Nearest Neighbors, Accuracy: 0.7509268487143712, F1-score: 0.3532934131736527

# %%
print(results)
# Out:
# [('Red Neuronal 1', <Functional name=functional_5, built=True>, <keras.src.callbacks.history.History object at 0x000002360405AD10>), ('Red Neuronal 2', <Functional name=functional_7, built=True>, <keras.src.callbacks.history.History object at 0x0000023605239110>), ('SVM', 0.778552920071756, 0.0), ('Random Forest', 0.7820809248554913, 0.32209737827715357), ('XGBoost', 0.7693508736960999, 0.3630573248407643), ('Logistic Regression', 0.7889509002724072, 0.3041825095057034), ('K-Nearest Neighbors', 0.7509268487143712, 0.3532934131736527)]

# %% [markdown]
# Modelo 1: Neural Network 1 - Loss: 0.4139, Accuracy: 0.8203
#
# Modelo 2: Neural Network 2 - Loss: 0.4326, Accuracy: 0.8157
#
# Modelo 3: SVM - Accuracy: 0.7788
#
# Modelo 4: Random Forest - Accuracy: 0.8111
#
# Modelo 5: XGBoost - Accuracy: 0.7926
#
# Modelo 6: Logistic Regression - Accuracy: 0.8111
#
# Modelo 7: K-Nearest Neighbors - Accuracy: 0.7788
